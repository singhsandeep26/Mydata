# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

df = pd.read_excel(r'C:\Users\ssing296\Desktop\Test\sample_data.xlsx')
df = df.groupby(['product','member_classification'])

print(df.first())
# Out:
#                                                 member_guid  subscription_id  \
# product               member_classification
# ACROBAT               EXISTING - ADDITIONAL              13             1012
#                       EXISTING - MIGRATE                113             1113
#                       EXISTING - REACTIVATE             303             1305
#                       NEW - FIRST SUBSCRIPTION           24             1023
#                       RESUBSCRIBER - DORMANT            386             1389
#                       RESUBSCRIBER - RECENT             494             1497
# ACROBAT READER MOBILE EXISTING - ADDITIONAL             314             1316
#                       NEW - FIRST SUBSCRIPTION            8             1007
# ADOBE FRESCO          EXISTING - ADDITIONAL             170             1171
#                       NEW - FIRST SUBSCRIPTION          117             1117
# AFTER EFFECTS         EXISTING - ADDITIONAL             439             1442
# ...
